# %%
# Load packages
import pandas as pd
import shared_functions as sf
from tqdm.notebook import tqdm

# %%
# Define file path and file name
file_path = '../data/raw/'
file_name = 'property-sales_new-york-city_2022'

# %%
# Load data
df = pd.read_parquet(f'{file_path}{file_name}_geocoded.parquet')

# %%
# Drop entries that could not be geocoded
df.dropna(subset=['location_lat', 'location_long'], inplace=True)

# %%
# Set authentication parameters
key = 'AIzaSyAWvONxSh0FU5tseu1q44BnNNpPTbI-yBY'
secret = 'p9e1PaofUIuc-8RJnOi--GOXLkM='

# %%
# Set additional parameters
size = '640x640'
maptype = 'satellite'

# %%
# Create list of parameters
params = [size, maptype, key, secret]

# %%
# Create list of zoom levels
zoom_levels = [16, 19]

# %%
# Initialize progress bar for pandas
tqdm.pandas()

# %%
# Save satellite images for all zoom levels
for zoom_level in zoom_levels:
    # Save satellite images for all entries by index value
    df.progress_apply(lambda row: sf.save_satellite_image(
        f'{file_path}/{maptype}-images_new-york-city_2022_{size}_{zoom_level}/{row.name}.png',
        False,
        row.location_lat,
        row.location_long,
        zoom_level,
        *params
        ), axis=1)
# Out:
#   0%|          | 0/85901 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 # Save satellite images for all zoom levels
#       2 for zoom_level in zoom_levels:
#       3     # Save satellite images for all entries by index value
# ----> 4     df.progress_apply(lambda row: sf.save_satellite_image(
#       5         f'{file_path}/{maptype}-images_new-york-city_2022_{size}_{zoom_level}/{row.name}.png',
#       6         False,
#       7         row.location_lat,
#       8         row.location_long,
#       9         zoom_level,
#      10         *params
#      11         ), axis=1)
#
# File ~/miniconda3/envs/bachelors_thesis/lib/python3.11/site-packages/tqdm/std.py:805, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     802 # Apply the provided function (in **kwargs)
# ...
